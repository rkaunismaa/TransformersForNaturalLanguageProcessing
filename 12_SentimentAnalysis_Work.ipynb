# %%
# Not sure if stuff is working with this notebook ... 
# Attempted stepping through ... OpenApi key has exceeded 
# RateLimitError: You exceeded your current quota, please check your plan and billing details.

# %%
import time
from datetime import date

startTime = time.time()
todaysDate = date.today()

# %% [markdown]
# #Sentiment Analysis with AllenNLP, Hugging Face and GPT-3
#
# Copyright 2022, Denis Rothman
#
# Resources
#
# [AllenNLP](https://demo.allennlp.org/sentiment-analysis)
#
# [Hugging Face Pipelines](https://huggingface.co/transformers/main_classes/pipelines.html)
#
# [Hugging Face Models](https://huggingface.co/models)
#
# [OpenAI GPT-3](https://beta.openai.com/examples/default-adv-tweet-classifier)

# %% [markdown]
# #Sentiment Analysis with AllenNLP

# %%
# !pip install allennlp==1.0.0 allennlp-models==1.0.0

# %% [markdown]
# Bash

# %%
# %%time
# !echo '{"sentence": "Whether or not you're enlightened by any of Derrida's lectures on the other and the self, Derrida is an undeniably fascinating and playful fellow."}' | \
allennlp predict https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz -
# Out:
# 2023-02-01 18:58:49.982510: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-01 18:58:51.072705: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-01 18:58:51.072777: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-01 18:58:51.072786: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-01 18:58:55,323 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2023-02-01 18:58:55,576 - INFO - cached_path - cache of https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz is up-to-date
# 2023-02-01 18:58:55,577 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/sst-roberta-large-2020.06.08.tar.gz from cache at /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac
# 2023-02-01 18:58:55,577 - INFO - allennlp.models.archival - extracting archive file /root/.allennlp/cache/8255466347f7b3a13b6bf71883dca4a02eefc30ce15004b8b41ba231b0e3de6d.f4aa9e5021ce7bf3c17488c8924b4aad654883a2f0b65528127695344bb741ac to temp dir /tmp/tmp1ko7ym0o
# 2023-02-01 18:59:02,943 - INFO - allennlp.common.params - dataset_reader.type = sst_tokens
# 2023-02-01 18:59:02,944 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# 2023-02-01 18:59:02,944 - INFO - allennlp.common.params - dataset_reader.manual_distributed_sharding = False
# 2023-02-01 18:59:02,944 - INFO - allennlp.common.params - dataset_reader.manual_multiprocess_sharding = False
# 2023-02-01 18:59:02,944 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2023-02-01 18:59:02,944 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2023-02-01 18:59:02,944 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.model_name = roberta-large
# 2023-02-01 18:59:02,944 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.namespace = tags
# 2023-02-01 18:59:02,944 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.max_length = None
# 2023-02-01 18:59:02,944 - INFO - allennlp.common.params - dataset_reader.token_indexers.tokens.tokenizer_kwargs = None
# 2023-02-01 18:59:06,136 - INFO - allennlp.common.params - dataset_reader.tokenizer = None
# 2023-02-01 18:59:06,136 - INFO - allennlp.common.params - dataset_reader.use_subtrees = True
# 2023-02-01 18:59:06,136 - INFO - allennlp.common.params - dataset_reader.granularity = 2-class
# 2023-02-01 18:59:06,136 - INFO - allennlp.common.params - validation_dataset_reader.type = sst_tokens
# 2023-02-01 18:59:06,136 - INFO - allennlp.common.params - validation_dataset_reader.max_instances = None
# 2023-02-01 18:59:06,136 - INFO - allennlp.common.params - validation_dataset_reader.manual_distributed_sharding = False
# 2023-02-01 18:59:06,136 - INFO - allennlp.common.params - validation_dataset_reader.manual_multiprocess_sharding = False
# 2023-02-01 18:59:06,136 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.type = pretrained_transformer_mismatched
# 2023-02-01 18:59:06,136 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2023-02-01 18:59:06,136 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.model_name = roberta-large
# 2023-02-01 18:59:06,136 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.namespace = tags
# 2023-02-01 18:59:06,137 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.max_length = None
# 2023-02-01 18:59:06,137 - INFO - allennlp.common.params - validation_dataset_reader.token_indexers.tokens.tokenizer_kwargs = None
# 2023-02-01 18:59:06,137 - INFO - allennlp.common.params - validation_dataset_reader.tokenizer = None
# 2023-02-01 18:59:06,137 - INFO - allennlp.common.params - validation_dataset_reader.use_subtrees = False
# 2023-02-01 18:59:06,137 - INFO - allennlp.common.params - validation_dataset_reader.granularity = 2-class
# 2023-02-01 18:59:06,137 - INFO - allennlp.common.params - type = from_instances
# 2023-02-01 18:59:06,137 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmp1ko7ym0o/vocabulary.
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.type = basic_classifier
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.regularizer = None
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.ddp_accelerator = None
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.text_field_embedder.type = basic
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = pretrained_transformer_mismatched
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.model_name = roberta-large
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.max_length = None
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.sub_module = None
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.train_parameters = True
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.last_layer_only = True
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.override_weights_file = None
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.override_weights_strip_prefix = None
# 2023-02-01 18:59:06,138 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.load_weights = True
# 2023-02-01 18:59:06,139 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.gradient_checkpointing = None
# 2023-02-01 18:59:06,139 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.tokenizer_kwargs = None
# 2023-02-01 18:59:06,139 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.transformer_kwargs = None
# 2023-02-01 18:59:06,139 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.sub_token_mode = avg
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-02-01 18:59:09,482 - INFO - allennlp.common.params - model.seq2vec_encoder.type = cls_pooler
# 2023-02-01 18:59:09,483 - INFO - allennlp.common.params - model.seq2vec_encoder.embedding_dim = 1024
# 2023-02-01 18:59:09,483 - INFO - allennlp.common.params - model.seq2vec_encoder.cls_is_last_token = False
# 2023-02-01 18:59:09,483 - INFO - allennlp.common.params - model.seq2seq_encoder = None
# 2023-02-01 18:59:09,483 - INFO - allennlp.common.params - model.feedforward = None
# 2023-02-01 18:59:09,483 - INFO - allennlp.common.params - model.dropout = 0.1
# 2023-02-01 18:59:09,483 - INFO - allennlp.common.params - model.num_labels = None
# 2023-02-01 18:59:09,483 - INFO - allennlp.common.params - model.label_namespace = labels
# 2023-02-01 18:59:09,483 - INFO - allennlp.common.params - model.namespace = tags
# 2023-02-01 18:59:09,483 - INFO - allennlp.common.params - model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7fbfd96507c0>
# 2023-02-01 18:59:09,484 - INFO - allennlp.nn.initializers - Initializing parameters
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _classification_layer.bias
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _classification_layer.weight
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.LayerNorm.bias
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.LayerNorm.weight
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.position_embeddings.weight
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.token_type_embeddings.weight
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.embeddings.word_embeddings.weight
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.dense.bias
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.output.dense.weight
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.key.bias
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.key.weight
# 2023-02-01 18:59:09,485 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.query.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.query.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.value.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.attention.self.value.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.intermediate.dense.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.intermediate.dense.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.LayerNorm.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.LayerNorm.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.dense.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.0.output.dense.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.dense.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.output.dense.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.key.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.key.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.query.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.query.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.value.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.attention.self.value.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.intermediate.dense.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.intermediate.dense.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.output.LayerNorm.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.output.LayerNorm.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.output.dense.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.1.output.dense.weight
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,486 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.output.dense.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.output.dense.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.key.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.key.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.query.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.query.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.value.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.attention.self.value.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.intermediate.dense.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.intermediate.dense.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.output.LayerNorm.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.output.LayerNorm.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.output.dense.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.10.output.dense.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.output.dense.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.output.dense.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.key.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.key.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.query.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.query.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.value.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.attention.self.value.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.intermediate.dense.bias
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.intermediate.dense.weight
# 2023-02-01 18:59:09,487 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.output.LayerNorm.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.output.LayerNorm.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.output.dense.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.11.output.dense.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.output.dense.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.output.dense.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.key.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.key.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.query.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.query.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.value.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.attention.self.value.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.intermediate.dense.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.intermediate.dense.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.output.LayerNorm.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.output.LayerNorm.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.output.dense.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.12.output.dense.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.output.dense.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.output.dense.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.self.key.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.self.key.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.self.query.bias
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.self.query.weight
# 2023-02-01 18:59:09,488 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.self.value.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.attention.self.value.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.intermediate.dense.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.intermediate.dense.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.output.LayerNorm.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.output.LayerNorm.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.output.dense.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.13.output.dense.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.output.dense.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.output.dense.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.self.key.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.self.key.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.self.query.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.self.query.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.self.value.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.attention.self.value.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.intermediate.dense.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.intermediate.dense.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.output.LayerNorm.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.output.LayerNorm.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.output.dense.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.14.output.dense.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.output.dense.bias
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.output.dense.weight
# 2023-02-01 18:59:09,489 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.self.key.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.self.key.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.self.query.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.self.query.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.self.value.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.attention.self.value.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.intermediate.dense.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.intermediate.dense.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.output.LayerNorm.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.output.LayerNorm.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.output.dense.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.15.output.dense.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.output.dense.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.output.dense.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.self.key.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.self.key.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.self.query.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.self.query.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.self.value.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.attention.self.value.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.intermediate.dense.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.intermediate.dense.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.output.LayerNorm.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.output.LayerNorm.weight
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.output.dense.bias
# 2023-02-01 18:59:09,490 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.16.output.dense.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.attention.output.dense.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.attention.output.dense.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.attention.self.key.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.attention.self.key.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.attention.self.query.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.attention.self.query.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.attention.self.value.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.attention.self.value.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.intermediate.dense.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.intermediate.dense.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.output.LayerNorm.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.output.LayerNorm.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.output.dense.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.17.output.dense.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.attention.output.dense.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.attention.output.dense.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.attention.self.key.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.attention.self.key.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.attention.self.query.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.attention.self.query.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.attention.self.value.bias
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.attention.self.value.weight
# 2023-02-01 18:59:09,491 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.intermediate.dense.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.intermediate.dense.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.output.LayerNorm.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.output.LayerNorm.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.output.dense.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.18.output.dense.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.attention.output.dense.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.attention.output.dense.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.attention.self.key.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.attention.self.key.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.attention.self.query.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.attention.self.query.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.attention.self.value.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.attention.self.value.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.intermediate.dense.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.intermediate.dense.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.output.LayerNorm.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.output.LayerNorm.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.output.dense.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.19.output.dense.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.output.dense.bias
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.output.dense.weight
# 2023-02-01 18:59:09,492 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.self.key.bias
# 2023-02-01 18:59:09,493 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.self.key.weight
# 2023-02-01 18:59:09,493 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.self.query.bias
# 2023-02-01 18:59:09,493 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.self.query.weight
# 2023-02-01 18:59:09,493 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.self.value.bias
# 2023-02-01 18:59:09,493 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.attention.self.value.weight
# 2023-02-01 18:59:09,493 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.2.intermediate.dense.bias
# ...
# 2023-02-01 18:59:09,496 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,496 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.dense.bias
# 2023-02-01 18:59:09,496 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.dense.weight
# 2023-02-01 18:59:09,496 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.key.bias
# 2023-02-01 18:59:09,496 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.key.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.query.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.query.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.value.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.value.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.intermediate.dense.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.intermediate.dense.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.LayerNorm.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.LayerNorm.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.dense.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.dense.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.dense.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.dense.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.key.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.key.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.query.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.query.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.value.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.value.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.LayerNorm.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.LayerNorm.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.dense.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.dense.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,497 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.dense.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.dense.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.weight
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.bias
# 2023-02-01 18:59:09,498 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.weight
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.bias
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.weight
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.bias
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.weight
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.bias
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.weight
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.bias
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.weight
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.bias
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.weight
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.bias
# 2023-02-01 18:59:09,499 - INFO - allennlp.nn.initializers -    _text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.weight
# 2023-02-01 18:59:10,164 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /tmp/tmp1ko7ym0o
# input 0:  {"sentence": "Whether or not youre enlightened by any of Derridas lectures on the other and the self, Derrida is an undeniably fascinating and playful fellow."}
# prediction:  {"logits": [1.9908612966537476, -1.5922558307647705], "probs": [0.9729623794555664, 0.027037598192691803], "token_ids": [0, 18259, 368, 3654, 6968, 241, 225, 6991, 4490, 1409, 3785, 1116, 34788, 10505, 281, 17601, 4123, 261, 627, 7443, 463, 627, 13367, 6, 495, 14385, 4347, 354, 260, 3194, 225, 37217, 506, 8631, 15647, 463, 5785, 2650, 506, 33796, 4, 2], "label": "1", "tokens": ["<s>", "Whether", "or", "not", "you", "re", "en", "light", "ened", "by", "any", "of", "Der", "rid", "as", "lect", "ures", "on", "the", "other", "and", "the", "self", ",", "D", "err", "ida", "is", "an", "und", "en", "iably", "f", "asc", "inating", "and", "play", "ful", "f", "ellow", ".", "</s>"]}
#
# CPU times: user 188 ms, sys: 13 ms, total: 201 ms
# Wall time: 23.3 s

# %% [markdown]
# # Sentiment Analysis with Hugging Face

# %%
# !pip install -q transformers

# %%
from transformers import pipeline
# Out:
# 2023-02-01 19:00:00.408501: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-01 19:00:01.010132: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-01 19:00:01.010181: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-01 19:00:01.010188: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
def classify(sequence,M):
    #DistilBertForSequenceClassification(default model)
    nlp_cls = pipeline('sentiment-analysis') 
    if M==1:
        print(nlp_cls.model.config)
    return nlp_cls(sequence)

# %%
seq=3
if seq==1:
    sequence="The battery on my Model9X phone doesn't last more than 6 hours and I'm unhappy about that."
if seq==2:
    sequence="The battery on my Model9X phone doesn't last more than 6 hours and I'm unhappy about that. I was really mad! I bought a Moel10x and things seem to be better. I'm super satisfied now."
if seq==3:
    sequence="The customer was very unhappy"
if seq==4:
    sequence="The customer was very satisfied"
print(sequence)
M=0 #display model cofiguration=1, default=0
CS=classify(sequence,M) 
print(CS)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# The customer was very unhappy
# [{'label': 'NEGATIVE', 'score': 0.9997097849845886}]

# %% [markdown]
# #Sentiment Analysis with GPT-3

# %%
try:
    import openai
except:
    # !pip install openai
    import openai

# %%
import os
import openai
# This is my key generated on Wednesday, February 1, 2023 ... 
os.environ['OPENAI_API_KEY'] = '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'
print(os.getenv('OPENAI_API_KEY'))
openai.api_key = os.getenv("OPENAI_API_KEY")
# Out:
# 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

# %%
openai.api_key
# Out:
# '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'

# %%
response = openai.Completion.create(
  engine="davinci",
  prompt="This is a Sentence sentiment classifier\nSentence: \"The customer was satisfied\"\nSentiment: Positive\n###\nSentence: \"The customer was not satisfied\"\nSentiment: Negative\n###\nSentence: \"The service was 👍\"\nSentiment: Positive\n###\nSentence: \"This is the link to the review\"\nSentiment: Neutral\n###\nSentence text\n\n\n1. \"I loved the new Batman movie!\"\n2. \"I hate it when my phone battery dies\"\n3. \"My day has been 👍\"\n4. \"This is the link to the article\"\n5. \"This new music video blew my mind\"\n\n\nSentence sentiment ratings:\n1: Positive\n2: Negative\n3: Positive\n4: Neutral\n5: Positive\n\n\n###\nSentence text\n\n\n1. \"I can't stand this product\"\n2. \"The service was bad! 😠\"\n3. \"Though the customer seemed unhappy she was in fact satisfied but thinking of something else at the time, which gave a false impression\"\n4. \"The support team was ❤️❤️\"\n5. \"Here is the link to the product.\"\n\n\nSentence sentiment ratings:\n",
  temperature=0.3,
  max_tokens=60,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0,
  stop=["###"]
)
r = (response["choices"][0])
print(r["text"])
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /tmp/ipykernel_44/3567967977.py:1 in <module>                                                    │
# │                                                                                                  │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_44/3567967977.py'                           │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/openai/api_resources/completion.py:25 in create           │
# │                                                                                                  │
# │   22 │   │                                                                                       │
# │   23 │   │   while True:                                                                         │
# │   24 │   │   │   try:                                                                            │
# │ ❱ 25 │   │   │   │   return super().create(*args, **kwargs)                                      │
# │   26 │   │   │   except TryAgain as e:                                                           │
# │   27 │   │   │   │   if timeout is not None and time.time() > start + timeout:                   │
# │   28 │   │   │   │   │   raise                                                                   │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/openai/api_resources/abstract/engine_api_resource.py:153  │
# │ in create                                                                                        │
# │                                                                                                  │
# │   150 │   │   │   api_key, api_base, api_type, api_version, organization, **params               │
# │   151 │   │   )                                                                                  │
# │   152 │   │                                                                                      │
# │ ❱ 153 │   │   response, _, api_key = requestor.request(                                          │
# │   154 │   │   │   "post",                                                                        │
# │   155 │   │   │   url,                                                                           │
# │   156 │   │   │   params=params,                                                                 │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/openai/api_requestor.py:227 in request                    │
# │                                                                                                  │
# │   224 │   │   │   request_id=request_id,                                                         │
# │   225 │   │   │   request_timeout=request_timeout,                                               │
# │   226 │   │   )                                                                                  │
# │ ❱ 227 │   │   resp, got_stream = self._interpret_response(result, stream)                        │
# │   228 │   │   return resp, got_stream, self.api_key                                              │
# │   229 │                                                                                          │
# │   230 │   @overload                                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/openai/api_requestor.py:620 in _interpret_response        │
# │                                                                                                  │
# │   617 │   │   │   ), True                                                                        │
# │   618 │   │   else:                                                                              │
# │   619 │   │   │   return (                                                                       │
# │ ❱ 620 │   │   │   │   self._interpret_response_line(                                             │
# │   621 │   │   │   │   │   result.content.decode("utf-8"),                                        │
# │   622 │   │   │   │   │   result.status_code,                                                    │
# │   623 │   │   │   │   │   result.headers,                                                        │
# │                                                                                                  │
# │ /usr/local/lib/python3.8/dist-packages/openai/api_requestor.py:680 in _interpret_response_line   │
# │                                                                                                  │
# │   677 │   │   # to better handle the "error while streaming" case.                               │
# │   678 │   │   stream_error = stream and "error" in resp.data                                     │
# │   679 │   │   if stream_error or not 200 <= rcode < 300:                                         │
# │ ❱ 680 │   │   │   raise self.handle_error_response(                                              │
# │   681 │   │   │   │   rbody, rcode, resp.data, rheaders, stream_error=stream_error               │
# │   682 │   │   │   )                                                                              │
# │   683 │   │   return resp                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# RateLimitError: You exceeded your current quota, please check your plan and billing details.

# %%
endTime = time.time()
elapsedTime = time.strftime("%H:%M:%S", time.gmtime(endTime - startTime))

print(todaysDate.strftime('# Run Date: %A, %B %d, %Y'))
print(f"# Run Time: {elapsedTime}")
